# %%
from chembl_webresource_client.new_client import new_client
import numpy as np
import pandas as pd

# %%
# Target search for coronavirus
target = new_client.target
target_query = target.search('coronavirus')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#                                     cross_references  \
# 0                                                 []
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4  [{'xref_id': 'P0C6U8', 'xref_name': None, 'xre...
# 5                                                 []
# 6  [{'xref_id': 'P0C6X7', 'xref_name': None, 'xre...
# 7                                                 []
#
#                                             organism  \
# 0                                        Coronavirus
# 1                                   SARS coronavirus
# 2                                 Feline coronavirus
# 3                             Human coronavirus 229E
# 4                                   SARS coronavirus
# 5  Middle East respiratory syndrome-related coron...
# 6                                   SARS coronavirus
# 7    Severe acute respiratory syndrome coronavirus 2
#
# ...

# %% [markdown]
# #### Select and retrieve bioactivity data for SARS coronavirus 3C-like proteinase (fifth entry)

# %% [markdown]
# We will assign the fifth entry (which corresponds to the target protein,
# coronavirus 3C-like proteinase) to the ***selected_target*** variable

# %%
target = new_client.target
target_query = target.search('langya')
targets2 = pd.DataFrame.from_dict(target_query)
targets2
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
target = new_client.target
target_query = target.search('nipah')
targets3 = pd.DataFrame.from_dict(target_query)
targets3
# Out:
#   cross_references     organism    pref_name  score  species_group_flag  \
# 0               []  Nipah virus  Nipah virus   18.0               False
#
#   target_chembl_id target_components target_type  tax_id
# 0     CHEMBL615055                []    ORGANISM  121791

# %%
target = new_client.target
target_query = target.search('hendra')
targets4 = pd.DataFrame.from_dict(target_query)
targets4
# Out:
# Empty DataFrame
# Columns: []
# Index: []
